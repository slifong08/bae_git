# %%
#!/bin/python

#sarahfong
#180621 hg38 migration

# %%
library(ggplot2)

# %%
bedpath = "/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/roadmap_multi_data/hg38/"

# %%
#file of the multiintersected roadmap enhancer peaks

bedfile ="percentile_short_hg38_multiintersect.bed" 

df <- read.table(paste0(bedpath, bedfile), sep = '\t', header = FALSE)

# %%
names(df) = c("chr", "start", "end", "sample_overlap", "sample_id", "percentile")
df$length = df$end - df$start
head(df)
# Out:
#   chr  start end   sample_overlap sample_id  percentile length
# 1 chr1  9988 10018 1              24         0.10        30
# 2 chr1 10018 10100 2              24,46      0.26        82
# 3 chr1 10100 10214 3              24,45,46   0.39       114
# 4 chr1 10214 10471 4              1,24,45,46 0.48       257
# 5 chr1 10471 10516 3              24,45,46   0.39        45
# 6 chr1 10516 10542 2              24,46      0.26        26

# %%
ggplot(df, aes(sample_overlap))+geom_histogram() +ggtitle("Hg38 Roadmap Enhancer Sample Overlap", subtitle = "Multi-intersect Roadmap") #+ scale_y_log10()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(df, aes(length))+geom_histogram() +ggtitle("Hg38 Roadmap Enhancer Lengths", subtitle = "Multi-intersect Roadmap") +scale_y_log10()+ scale_x_log10()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”Warning message:
# “Removed 2 rows containing missing values (geom_bar).”
# plot without title

# %%
ggplot(df, aes(x= sample_overlap, y=length))+geom_point() +ggtitle("Hg38 Roadmap Enhancer Sample Overlap v. Lengths", subtitle = "Multi-intersect Roadmap") #+ scale_y_log10()
# Out:
# plot without title

# %%
ggplot(df, aes(sample_overlap))+geom_histogram() +ggtitle("Hg38 Roadmap Enhancer Sample Overlap", subtitle = "Multi-intersect Roadmap") + scale_y_log10()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
quantile(df$sample_overlap, 0.95)
# Out:
# 95%
#  21

# %%
a =subset(df, sample_overlap >50)
a
# Out:
#         chr  start     end       sample_overlap
# 28750   chr1  8463634   8463635  51
# 28752   chr1  8463641   8463651  51
# 28754   chr1  8463676   8463700  51
# 28755   chr1  8463700   8463801  52
# 28756   chr1  8463801   8463816  51
# 122218  chr1 27418528  27418547  51
# 122224  chr1 27418639  27418641  51
# 122225  chr1 27418641  27418666  52
# 122226  chr1 27418666  27418745  53
# 122227  chr1 27418745  27418770  52
# 122228  chr1 27418770  27418780  51
# 124432  chr1 27542666  27542713  51
# 124433  chr1 27542713  27542732  52
# 124434  chr1 27542732  27542749  53
# 124435  chr1 27542749  27542762  54
# 124436  chr1 27542762  27542796  53
# 124437  chr1 27542796  27542806  54
# 124438  chr1 27542806  27542807  53
# 124439  chr1 27542807  27542834  54
# 124440  chr1 27542834  27542975  53
# 124441  chr1 27542975  27542993  52
# 124442  chr1 27542993  27543023  53
# 124443  chr1 27543023  27543034  52
# 124444  chr1 27543034  27543108  53
# 124445  chr1 27543108  27543159  52
# ...

# %%
#the 99th percentile of overlapping roadmap multi-intersect enhancer peaks

bedfile99 = "99_short_multiintersect_roadmap.bed"
df99 = pandas.read_table("%s%s"%(bedpath, bedfile99), sep = '\t', header=-1)
num99 = df99[0].unique()
for chr_num in num99:
    chr_df = df99.loc[df99[0]== chr_num]
    chr_df = chr_df[[0,1,2]]
    chr_df.to_csv("%s%s_%s" %(bedpath, chr_num, bedfile99), index = False, header = False, sep = '\t')

# %%
#the 90th percentile of villar overlapping roadmap enhancer peaks
datapath = "/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/"
bedfile = "hspecific_villar_bae_hq_aln.bed"

df = pandas.read_table("%s%s"%(datapath, bedfile), sep = '\t')
num = df['v-chr'].unique()
for chr_num in num:
    chr_df = df.loc[df["v-chr"]== chr_num]
    chr_df.to_csv("%s%s_%s" %(datapath, chr_num, bedfile), index = False, header = False, sep = '\t')
