# %%
#180601

#sarahfong
#biopython is loaded in the sf_test env with 'conda install -c bioconda biopython'

# %%
import sys
import glob
#import pandas

#SARAH- ADD THE PATH WITH BIOPYTHON
bio_package = '/home/fongsl/.conda/envs/sf_test/lib/python3.6/site-packages'
if bio_package not in sys.path:

    sys.path.append('/home/fongsl/.conda/envs/sf_test/lib/python3.6/site-packages')
sys.path
# Out:
# ['',
#  '/home/fongsl/.conda/envs/sf_test/lib/python36.zip',
#  '/home/fongsl/.conda/envs/sf_test/lib/python3.6',
#  '/home/fongsl/.conda/envs/sf_test/lib/python3.6/lib-dynload',
#  '/home/fongsl/.conda/envs/sf_test/lib/python3.6/site-packages',
#  '/home/fongsl/.conda/envs/sf_test/lib/python3.6/site-packages/IPython/extensions',
#  '/gpfs22/home/fongsl/.ipython']

# %%
from Bio import AlignIO
from Bio import SeqIO

# %%
# path to data

datapath = "/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/"

# %%
#make a list of the MAF files separated by chromosome

maf_list = glob.glob("%sparsed*.maf" % datapath)
# Out:
# ['/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr2.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr8.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr14.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr15.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr4.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr17.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr3.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr6.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chrX.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr1.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr22.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr21.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr9.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr5.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr12.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr18.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr19.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr7.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr11.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr16.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr13.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr10.maf', '/dors/capra_lab/users/fongsl/broadly_active_enhancers/data/villar_ref_data/villar_maf/parsed_chr20.maf']

# %%
for MAF_FILE in maf_list:
# this grafted from Abin's script. Credits to him. 

    chr_num = ((MAF_FILE.split('/')[-1]).split('_')[1]).split('.')[0]
    print("working on ", chr_num)
    out_file = open("%shg19_villar_bae_hspec_%s.bed" %(datapath, chr_num), 'w')
    out_file_con = open("%shg19_villar_bae_con_%s.bed" %(datapath, chr_num), 'w')
    maf = AlignIO.parse(MAF_FILE, "maf")
    count = 0 
    for block in maf: 
        count += 1
        
        store_homolog_line = []
        s_count = 0
        for row in block: 
            
            ### this is where the parsing happens.... what is the .id part?
            #print(row)
            species = row.id.split('.')[0]
        
            blockchr = row.id.split('.')[1]
        
            start = row.annotations['start']
            
            end =  row.annotations['start'] + row.annotations['size'] + 1 
            
            if row.annotations['strand'] == 1:
                strand = "+" 
            elif row.annotations['strand'] == -1: 
                strand = "-"
            else: 
                raise ValueError('strand parsing did not work')     
            
            store_homolog_line.append([blockchr, start, end, strand, species, str(s_count)])
        store_homolog_line = [value for v in store_homolog_line for value in v]
        if s_count ==1:
            out_file.write('\t'.join(map(str,store_homolog_line)) + '\n')
        else:
            out_file_con.write('\t'.join(map(str,store_homolog_line)) + '\n')   
    out_file.close()
# Out:
# working on  chr2
# /home/fongsl/.conda/envs/sf_test/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# ...
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
# Empty DataFrame
# Columns: [chr, start, end, strand, species_count]
# Index: []
